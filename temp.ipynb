# %%
import pandas as pd 
import numpy as np

# %%
data = "./generation_eval.csv"

# %%
df=pd.read_csv(data)

# %%
df = pd.DataFrame(df)

# %%
print(df)
# Out:
#                                       vulnerable_code  \
# 0                        new WirelessType= option.\n-
# 1   ISOM_DECREASE_SIZE_NO_ERR(ptr, 18)\ntag_size -...
# 2   name: Initialize CodeQL\nuses: github/codeql-a...
# 3   Don't conflate 0 and undefined when checking i...
# 4   # There is no hostname validation when DEBUG=T...
# 5   return circle.name;\nreturn circle.name;\n//re...
# 6   <a href="$xwiki.getURL('XWiki.XWikiLogout', 'l...
# 7   add csrf token\nadd random int to filenmae\nch...
# 8   if (!php_var_unserialize(&pmembers, &p, s + bu...
# 9                           if (bvlc_length < 4) {\n-
# 10  import java.nio.file.StandardOpenOption;\nfina...
# 11  if (isteq(list[idx].n, ist("host")))\n/* compl...
# 12  apcu_clear_cache();\n$log->logAction(FroxlorLo...
# 13  cherokee_buffer_is_empty (&conn->validator->us...
# 14  sort_attr = "#{query.table_name}.#{sort_attr}"...
# 15  for (j = 0; j < size; j++) {\nr_cons_printf ("...
# ...
